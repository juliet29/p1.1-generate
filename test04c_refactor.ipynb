# %%
from processor import Processor

# %%
p = Processor()

# %%
PATH = 'plans/ostwald2011_plans/ostwald_alpha.png'
p.read_plan(PATH, DEBUG=True)

# %%
p.configure_graph(DEBUG=True)

# %%
p1 = Processor()
PATH = "plans/ostwald2011_plans/ostwald_beta.png"
p1.read_plan(PATH=PATH, DEBUG=True)

# %%
p1.configure_graph(DEBUG=True)

# %%
p2 = Processor()
PATH = "plans/ostwald2011_plans/ostwald_gamma.png"
p2.read_plan(PATH=PATH, num_doors=8, DEBUG=True)

# %%
p2.configure_graph(DEBUG=True)

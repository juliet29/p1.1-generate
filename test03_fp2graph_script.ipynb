# %%
from fp2graph import *

# %%
PATH = 'plans/fp02.png'
f = FloorPlan2Graph(PATH)

# %%
f.image2tensor()
f.view_plan_image()
# Out:
# <module 'matplotlib.pyplot' from '/Users/julietnwagwuume-ezeoke/_UILCode/gqe-phd/gqenv/lib/python3.9/site-packages/matplotlib/pyplot.py'>

# %%
f.segment_tensor()
f.view_plan_segments()
# Out:
# <module 'matplotlib.pyplot' from '/Users/julietnwagwuume-ezeoke/_UILCode/gqe-phd/gqenv/lib/python3.9/site-packages/matplotlib/pyplot.py'>

# %%
# np.unique(f.tensor_labels) 
# # TODO ISSUE -> maybe 0 doesnt count as a label?

# %%
# f.all_region_props

# %%
# len(f.regions)

# %%
f.array2shapely()
_ = f.view_plan_shapely()
# TODO issue here...

# %%
f.shapely2graph()
f.view_graph()
# technically wrong for the graph above..
# Out:
# <module 'matplotlib.pyplot' from '/Users/julietnwagwuume-ezeoke/_UILCode/gqe-phd/gqenv/lib/python3.9/site-packages/matplotlib/pyplot.py'>

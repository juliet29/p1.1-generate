# %%
from fp2graph import *

# %%
PATH = 'plans/fp02.png'
f = FloorPlan2Graph(PATH)

# %%
f.image2tensor()
f.view_plan_image()
# Out:
# <module 'matplotlib.pyplot' from '/Users/julietnwagwuume-ezeoke/_UILCode/gqe-phd/gqenv/lib/python3.9/site-packages/matplotlib/pyplot.py'>

# %%
f.segment_tensor()
f.view_plan_segments()
# Out:
# <module 'matplotlib.pyplot' from '/Users/julietnwagwuume-ezeoke/_UILCode/gqe-phd/gqenv/lib/python3.9/site-packages/matplotlib/pyplot.py'>

# %%
f.array2shapely()
_ = f.view_plan_shapely()
# TODO issue here...

# %%
np.unique(f.tensor_labels) 
# ISSUE resolved -> maybe 0 doesnt count as a label? YES!
# Out:
# array([1, 2, 3, 4], dtype=int8)

# %%
f.all_region_props

# %%
len(f.regions)
# Out:
# 4

# %%
g1, g2, g3 = f.shapely2graph()
# f.view_graph()
# # TODO technically wrong for the graph above..
